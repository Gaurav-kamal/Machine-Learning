# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ecommerce Customers.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
x=df[['Avg. Session Length']]
y=df['Yearly Amount Spent']

# %%
x.head()
# Out:
#    Avg. Session Length
# 0            34.497268
# 1            31.926272
# 2            33.000915
# 3            34.305557
# 4            33.330673

# %%
y.head()
# Out:
# 0    587.951054
# 1    392.204933
# 2    487.547505
# 3    581.852344
# 4    599.406092
# Name: Yearly Amount Spent, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)
print(pred)
# Out:
# [490.13626096 528.82060695 574.96714869 537.76621278 478.46920524
#  499.56207794 533.64448509 499.27919462 534.89713094 457.99642478
#  507.48041238 480.30657284 497.10387913 460.13055227 471.95082644
#  526.41906398 490.31559526 485.95490812 505.06817922 490.56268182
#  522.82364275 466.1471203  511.36071228 485.08000988 529.22469073
#  487.126751   476.16643376 516.41408771 437.77494393 474.89040565
#  455.78971736 440.17941148 493.10287657 502.71464635 479.99816374
#  475.67503412 480.84414585 517.22663728 482.85431598 474.08958443
#  474.52823587 567.67936022 491.28988304 498.07713168 532.39958394
#  509.14727223 497.57533314 528.92313245 516.2915218  501.49195866
#  493.01444438 493.76979361 492.88701629 464.5179837  492.4337159
#  467.32025181 516.7772603  486.27722952 465.82326661 497.14156517
#  478.102164   477.07337666 476.93730369 444.25890016 504.35386705
#  507.14886666 468.24649904 527.48003914 491.062306   527.89569904
# ...

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
m = lr.coef_
b = lr.intercept_

# %%
new=[]
for i in x_test.values:
  y=m*(i)+b
  new.append(y)

print(new)
# Out:
# [array([490.13626096]), array([528.82060695]), array([574.96714869]), array([537.76621278]), array([478.46920524]), array([499.56207794]), array([533.64448509]), array([499.27919462]), array([534.89713094]), array([457.99642478]), array([507.48041238]), array([480.30657284]), array([497.10387913]), array([460.13055227]), array([471.95082644]), array([526.41906398]), array([490.31559526]), array([485.95490812]), array([505.06817922]), array([490.56268182]), array([522.82364275]), array([466.1471203]), array([511.36071228]), array([485.08000988]), array([529.22469073]), array([487.126751]), array([476.16643376]), array([516.41408771]), array([437.77494393]), array([474.89040565]), array([455.78971736]), array([440.17941148]), array([493.10287657]), array([502.71464635]), array([479.99816374]), array([475.67503412]), array([480.84414585]), array([517.22663728]), array([482.85431598]), array([474.08958443]), array([474.52823587]), array([567.67936022]), array([491.28988304]), array([498.
# ...

# %%
pred3=pd.DataFrame(new)
pred3
# Out:
#               0
# 0    490.136261
# 1    528.820607
# 2    574.967149
# 3    537.766213
# 4    478.469205
# ..          ...
# 145  402.642009
# 146  523.956277
# 147  511.348061
# 148  510.450600
# 149  532.239624
#
# [150 rows x 1 columns]

# %%
pred_new=pd.DataFrame(pred)
pred_new
# Out:
#               0
# 0    490.136261
# 1    528.820607
# 2    574.967149
# 3    537.766213
# 4    478.469205
# ..          ...
# 145  402.642009
# 146  523.956277
# 147  511.348061
# 148  510.450600
# 149  532.239624
#
# [150 rows x 1 columns]

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(pred_new, pred3))
print('MSE:', metrics.mean_squared_error(pred_new, pred3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(pred_new, pred3)))
# Out:
# MAE: 0.0
# MSE: 0.0
# RMSE: 0.0
